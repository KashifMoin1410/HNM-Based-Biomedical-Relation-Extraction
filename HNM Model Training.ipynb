# %%
import torch
import torch.nn as nn
from transformers import BertModel, BertTokenizer

class RelationExtractionModel(nn.Module):
    def __init__(self, bert_model_name='microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract', embedding_dim=768):
        super(RelationExtractionModel, self).__init__()
        # Initialize the pre-trained PubMedBERT model to obtain contextual embeddings.
        self.bert = BertModel.from_pretrained(bert_model_name)
        # Dropout layer to prevent overfitting during training.
        self.dropout = nn.Dropout(p=0.1)
        # Projecting the [CLS] token representation into the desired relation embedding space.
        self.fc = nn.Linear(embedding_dim, embedding_dim)
        
    def forward(self, input_ids, attention_mask):
        # Pass the input tokens through the PubMedBERT model to obtain hidden states.
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        cls_output = outputs.pooler_output  
        # Apply dropout for regularization to reduce overfitting.
        cls_output = self.dropout(cls_output)
        relation_embedding = self.fc(cls_output)
        return relation_embedding

if __name__ == "__main__":
    # Initialize the tokenizer associated with PubMedBERT.
    tokenizer = BertTokenizer.from_pretrained('microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract')
    # Instantiate the relation extraction model.
    model = RelationExtractionModel()

    # Define a sample sentence for relation extraction.
    sample_text = "The sodium/iodide symporter is associated with congenital hypothyroidism."
    # Tokenize the input sentence to convert it into input IDs and attention masks suitable for our model.
    inputs = tokenizer(sample_text, return_tensors="pt", padding=True, truncation=True)

    # Perform a forward pass through the model to obtain the relation embedding.
    embedding = model(input_ids=inputs['input_ids'], attention_mask=inputs['attention_mask'])
    print("Relation Embedding:", embedding.shape)
# Out:
# /Users/kashifmoin/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /Users/kashifmoin/anaconda3/lib/python3.11/site-packages/transformers/modeling_utils.py:446: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location="cpu")
# Some weights of the model checkpoint at microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Relation Embedding: torch.Size([1, 768])

# %%
import json
import numpy as np
import torch
from transformers import BertModel, BertTokenizer
from sklearn.metrics.pairwise import cosine_similarity

# Function to load a BioC JSON file
def load_bioc_file(filename):
    """
    Loads a BioC JSON file and returns its content as a Python dictionary.
    Returns:
        dict: Parsed JSON content.
    """
    with open(filename, 'r') as f:
        data = json.load(f)
    return data

# Function to extract relation texts from a BioC JSON document
# For simplicity, we construct a relation text as: "entity1 - relation_type - entity2"
def extract_relation_texts(bioc_data):
    relation_texts = []
    # Iterate over documents
    for doc in bioc_data.get("documents", []):
        
        '''Create a mapping from annotation id to its text for quick lookup.
        In BioC the relations refer to identifiers from the annotations. 
        Here we use the "text" from each annotation.'''
        annotation_texts = {}
        for passage in doc.get("passages", []):
            for ann in passage.get("annotations", []):
                # Using annotation_texts id as key.
                annotation_texts[ann["id"]] = ann["text"]
        
        # For each relation in the document, constructing a simple string.
        for rel in doc.get("relations", []):
            infons = rel.get("infons", {})
            # Retrieving texts of the related entities using their annotation_texts IDs.
            entity1 = infons.get("entity1", "Entity1")
            entity2 = infons.get("entity2", "Entity2")
            rel_type = infons.get("type", "Relation")
            # Construct a simple relation text.
            rel_text = f"{entity1} - {rel_type} - {entity2}"
            relation_texts.append(rel_text)
    return relation_texts

# Function to compute PubMedBERT embedding for a given text.
def get_relation_embedding(text, tokenizer, model):
    """
    Computes the PubMedBERT embedding for a given text.
    Returns:
        np.ndarray: Embedding vector.
    """
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    with torch.no_grad():
        outputs = model(**inputs)
    embedding = outputs.pooler_output  # shape = [1, embedding_dim]
    return embedding.squeeze(0).cpu().numpy()

# Function to compute embeddings and cosine similarity matrix for a list of relation texts.
def compute_similarity_matrix(relation_texts, tokenizer, model):
    """
    Computes embeddings and cosine similarity matrix for a list of relation texts. 
    Returns:
        tuple: Cosine similarity matrix and embeddings array.
    """
    embeddings = []
    for text in relation_texts:
        emb = get_relation_embedding(text, tokenizer, model)
        embeddings.append(emb)
    embeddings = np.vstack(embeddings)  # shape: [num_relations, embedding_dim]
    sim_matrix = cosine_similarity(embeddings)
    return sim_matrix, embeddings

# Main execution
if __name__ == "__main__":
    # Load the BioC JSON file.
    bioc_data = load_bioc_file("Train.BioC.JSON")
    
    # Extracting the relation texts from the dataset.
    relation_texts = extract_relation_texts(bioc_data)
    print("Extracted Relation Texts:")
    for rt in relation_texts:
        print(rt)
    
    # Load the PubMedBERT model and tokenizer.
    model_name = "microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract"
    tokenizer = BertTokenizer.from_pretrained(model_name)
    model = BertModel.from_pretrained(model_name)
    
    # Compute the cosine similarity matrix among the relation embeddings.
    sim_matrix, embeddings = compute_similarity_matrix(relation_texts, tokenizer, model)
    
    # Print the cosine similarity matrix
    print("\nCosine Similarity Matrix:")
    for i, text_i in enumerate(relation_texts):
        for j, text_j in enumerate(relation_texts):
            print(f"Similarity between '{text_i}' and '{text_j}': {sim_matrix[i][j]:.4f}")
# Out:
# Extracted Relation Texts:
# 3175 - Association - D003924
# D005947 - Positive_Correlation - 3630
# D005947 - Association - D003924
# 50489 - Bind - D008358
# D001943 - Positive_Correlation - c|INS|5382|C
# D001943 - Positive_Correlation - c|DEL|4153|A
# D001943 - Positive_Correlation - rs28897672
# D010051 - Positive_Correlation - c|INS|5382|C
# D010051 - Positive_Correlation - c|DEL|4153|A
# D010051 - Positive_Correlation - rs28897672
# c|INS|5382|C - Positive_Correlation - D061325
# c|DEL|4153|A - Positive_Correlation - D061325
# rs28897672 - Positive_Correlation - D061325
# OMIM:604370 - Positive_Correlation - c|INS|5382|C
# OMIM:604370 - Positive_Correlation - c|DEL|4153|A
# OMIM:604370 - Positive_Correlation - rs28897672
# 672 - Association - D001943
# 672 - Association - D010051
# 672 - Association - OMIM:604370
# 672 - Association - D061325
# D007980 - Positive_Correlation - D004409
# D001058 - Negative_Correlation - D007980
# D001058 - Negative_Correlation - D004409
# D001058 - Negative_Correlation - D010300
# D014594 - Association - 84084
# 84084 - Positive_Correlation - D014750
# 84084 - Positive_Correlation - D014747
# 84084 - Positive_Correlation - D017239
# 84084 - Positive_Correlation - D004317
# 5530 - Negative_Correlation - D016559
# 5530 - Negative_Correlation - D016572
# D006530 - Positive_Correlation - D003404
# D016559 - Positive_Correlation - D007674
# D007676 - Positive_Correlation - D003404
# D016572 - Positive_Correlation - D007674
# 6647 - Association - D000690
# rs80265967 - Negative_Correlation - D000690
# 410 - Association - D007966
# rs74315458 - Positive_Correlation - D007966
# 2706 - Association - C567134
# rs143117125 - Positive_Correlation - D006938
# D006938 - Association - 255738
# 255738 - Association - D002784
# 255738 - Association - D006937
# rs137852912 - Positive_Correlation - D006938
# D006937 - Association - rs137852912
# 1410 - Association - C563319
# 1674 - Association - C563319
# 57190 - Association - C564969
# 57190 - Association - C535683
# 57190 - Association - D009135
# C563319 - Positive_Correlation - c|DEL|-19_+73|92
# C563319 - Association - 57190
# 7290 - Association - D004062
# D002395 - Positive_Correlation - D009202
# D009202 - Positive_Correlation - D004837
# D004837 - Positive_Correlation - D017682
# D018487 - Positive_Correlation - D004837
# D013927 - Positive_Correlation - D001241
# C406224 - Negative_Correlation - D001172
# C406224 - Negative_Correlation - D010003
# C406224 - Comparison - D000894
# C406224 - Negative_Correlation - D001168
# 5743 - Negative_Correlation - C406224
# c|INS||9 - Positive_Correlation - D014929
# 7466 - Association - D014929
# p|INS|344_345|AFF - Positive_Correlation - D014929
# D012701 - Positive_Correlation - D008881
# C079198 - Comparison - D005472
# D006331 - Negative_Correlation - C079198
# D066126 - Negative_Correlation - C079198
# D066126 - Positive_Correlation - C032348
# D002637 - Positive_Correlation - C032348
# D002637 - Positive_Correlation - D005472
# C032348 - Negative_Correlation - C079198
# D002037 - Positive_Correlation - C032348
# D005472 - Negative_Correlation - D009369
# D005472 - Positive_Correlation - D066126
# D005472 - Positive_Correlation - C032348
# D005472 - Positive_Correlation - D002037
# D010862 - Positive_Correlation - D013226
# D010862 - Positive_Correlation - D001308
# D010862 - Positive_Correlation - D012640
# 26191 - Association - D001327
# 26191 - Association - D003922
# 26191 - Association - D001171
# rs2476601 - Positive_Correlation - D001327
# rs2476601 - Positive_Correlation - D003922
# rs2476601 - Positive_Correlation - D001171
# rs2488457 - Association - rs1217412
# rs1143634 - Association - rs1143627
# 4790 - Association - D009369
# 3553 - Association - D009369
# 3553 - Association - 4790
# 3553 - Association - D013274
# D013274 - Positive_Correlation - rs1143634
# rs1143627 - Positive_Correlation - D013274
# D002945 - Negative_Correlation - C004656
# 841 - Positive_Correlation - D002945
# 836 - Positive_Correlation - D002945
# C004656 - Negative_Correlation - 1508
# C004656 - Negative_Correlation - 841
# C004656 - Negative_Correlation - 836
# C004656 - Positive_Correlation - D009336
# C004656 - Negative_Correlation - D013438
# C004656 - Positive_Correlation - D007674
# D007674 - Positive_Correlation - D007069
# D009369 - Negative_Correlation - D007069
# D010656 - Positive_Correlation - D006973
# 10400 - Association - D065626
# D010714 - Conversion - D010713
# rs7946 - Association - D010713
# rs7946 - Association - D010714
# rs7946 - Positive_Correlation - D065626
# rs1155974 - Association - D009765
# rs2073162 - Positive_Correlation - D003924
# rs2073162 - Association - D009765
# rs1155794 - Positive_Correlation - D003924
# D003924 - Positive_Correlation - rs1155974
# D003924 - Positive_Correlation - D005947
# rs2073163 - Positive_Correlation - D003924
# rs2073163 - Association - D009765
# D005947 - Association - rs1155794
# D005947 - Association - rs2073163
# D009765 - Association - rs11798018
# D009765 - Association - rs4828037
# D009765 - Association - rs5966709
# 64102 - Association - D003924
# 64102 - Association - D005947
# 64102 - Association - D003920
# 64102 - Association - D009765
# 7097 - Association - D015212
# 7099 - Association - D015212
# p|SUB|P|631|H - Negative_Correlation - D015212
# rs4986790 - Negative_Correlation - D015212
# 64127 - Association - D015212
# D003424 - Association - 64127
# D003424 - Association - 10392
# 2261 - Association - D000130
# rs28931614 - Positive_Correlation - D000130
# 11144 - Association - D007247
# 11144 - Association - D016649
# 4439 - Association - D016649
# D007247 - Association - 4439
# D007247 - Association - rs2227914
# D007247 - Association - rs2075789
# rs2227914 - Association - D016649
# D016649 - Association - rs2075789
# 3663 - Association - D008180
# 3663 - Association - D001172
# rs729302 - Positive_Correlation - D001172
# c|DEL|-1607|G - Positive_Correlation - C535531
# D055959 - Association - c|DEL|-1607|G
# c|Allele|D|-1607 - Positive_Correlation - D055959
# 4312 - Association - D055959
# C535531 - Association - 4312
# D004827 - Positive_Correlation - D010400
# D010406 - Positive_Correlation - D004827
# D006849 - Positive_Correlation - rs121908864
# D006980 - Positive_Correlation - rs121908864
# 7253 - Association - D006849
# 7253 - Association - D006980
# C563786 - Association - 7253
# C563786 - Positive_Correlation - rs121908864
# 185 - Association - D019462
# 185 - Association - D007022
# D013575 - Association - 185
# D013575 - Association - rs5186
# rs5186 - Positive_Correlation - D019462
# rs5186 - Association - D007022
# C537689 - Positive_Correlation - rs267607116
# C537689 - Positive_Correlation - rs201893408
# C537689 - Positive_Correlation - rs267607117
# C536132 - Positive_Correlation - rs267607116
# C536132 - Positive_Correlation - rs201893408
# C536132 - Positive_Correlation - rs267607117
# rs267607116 - Positive_Correlation - C537699
# rs267607116 - Positive_Correlation - C536133
# rs267607116 - Positive_Correlation - C536293
# rs267607116 - Positive_Correlation - D008103
# rs201893408 - Positive_Correlation - C537699
# rs201893408 - Positive_Correlation - C536133
# rs201893408 - Positive_Correlation - C536293
# rs201893408 - Positive_Correlation - D008103
# rs267607117 - Positive_Correlation - C537699
# rs267607117 - Positive_Correlation - C536133
# rs267607117 - Positive_Correlation - C536293
# rs267607117 - Positive_Correlation - D008103
# OMIM:613550 - Positive_Correlation - rs267607116
# OMIM:613550 - Positive_Correlation - rs201893408
# OMIM:613550 - Positive_Correlation - rs267607117
# 91147 - Association - C537689
# 91147 - Association - C536132
# 91147 - Association - C537699
# 91147 - Association - C536133
# 91147 - Association - C536293
# 91147 - Association - D008103
# 91147 - Association - OMIM:613550
# D010300 - Positive_Correlation - c|INDEL||43
# 6532 - Association - D010300
# D000082 - Positive_Correlation - D003866
# D000082 - Positive_Correlation - D017114
# D000082 - Positive_Correlation - D001929
# D055752 - Association - rs1052133
# D002289 - Association - rs1052133
# D000230 - Positive_Correlation - rs1052133
# D018288 - Positive_Correlation - rs1052133
# C024829 - Association - 4968
# D000077192 - Positive_Correlation - rs1052133
# 4968 - Positive_Correlation - D055752
# 4968 - Positive_Correlation - D002289
# 4968 - Positive_Correlation - D000230
# 4968 - Positive_Correlation - D018288
# 4968 - Association - D000077192
# 4968 - Association - D008175
# D008175 - Positive_Correlation - rs1052133
# 9365 - Association - D000075222
# 16591 - Association - D001161
# 16591 - Association - D000075222
# rs1207568 - Positive_Correlation - D000075222
# D012640 - Association - 60463
# D013226 - Positive_Correlation - 60463
# D013226 - Positive_Correlation - 24770
# D010862 - Positive_Correlation - D013226
# D010862 - Positive_Correlation - 60463
# D010862 - Positive_Correlation - 24770
# 60463 - Association - D007249
# 24770 - Bind - 60463
# D007249 - Association - 4313
# D007249 - Association - 9516
# D007249 - Association - 7079
# D007249 - Association - 7078
# D007249 - Association - 7076
# D007249 - Association - 7040
# 1675 - Positive_Correlation - 718
# 629 - Positive_Correlation - 1675
# 629 - Positive_Correlation - 718
# 718 - Positive_Correlation - D014280
# D009765 - Association - 718
# D009765 - Association - 9370
# D009765 - Positive_Correlation - D014280
# D008055 - Association - 5468
# D008055 - Association - 1051
# D008055 - Association - 1050
# D008055 - Association - 2170
# D008055 - Association - 2168
# D008055 - Association - 5346
# D008055 - Association - 1066
# D008055 - Association - 3991
# D008055 - Association - 4023
# D008055 - Association - 2194
# D008055 - Association - 6319
# D008055 - Association - 84649
# D008055 - Association - 8694
# D008055 - Association - 948
# 27202 - Bind - 718
# 27202 - Positive_Correlation - D014280
# 3630 - Association - 3667
# 3630 - Association - 3643
# D046150 - Positive_Correlation - c|DUP|899|C|
# D046150 - Positive_Correlation - p|SUB|R|211|H
# D046150 - Association - 2690
# C563867 - Positive_Correlation - c|DUP|899|C|
# C563867 - Positive_Correlation - p|SUB|R|211|H
# C563867 - Association - 2690
# 1584 - Association - D006973
# D006973 - Association - 1585
# D006973 - Positive_Correlation - rs6387
# D006973 - Positive_Correlation - rs6410
# D006973 - Positive_Correlation - rs4539
# D006973 - Positive_Correlation - rs1799998
# D000236 - Association - 1584
# D000236 - Association - 1585
# D000236 - Association - rs6387
# D000236 - Association - rs6410
# D000236 - Association - rs4539
# D000236 - Association - rs1799998
# c|SUB|C|592|T - Positive_Correlation - D005124
# c|SUB|C|592|T - Positive_Correlation - C538287
# D002386 - Positive_Correlation - c|SUB|C|592|T
# p|SUB|R|198|W - Positive_Correlation - D005124
# p|SUB|R|198|W - Positive_Correlation - D002386
# p|SUB|R|198|W - Positive_Correlation - C538287
# 2703 - Association - D005124
# 2703 - Association - D002386
# C538287 - Association - 2703
# 183 - Association - D002312
# D002312 - Positive_Correlation - rs699
# 112744 - Association - D011696
# 112744 - Association - D016553
# D001327 - Association - 112744
# rs763780 - Association - D011696
# D016553 - Association - rs763780
# 7515 - Association - D008180
# 7515 - Association - D005076
# rs25487 - Positive_Correlation - D008180
# D005076 - Positive_Correlation - rs25487
# 20850 - Association - D000740
# 16452 - Association - D000740
# 74427 - Positive_Correlation - 13856
# 114715 - Positive_Correlation - 13856
# 114716 - Positive_Correlation - 13856
# 216233 - Association - D000740
# 216233 - Positive_Correlation - 13856
# 12702 - Positive_Correlation - 13856
# 13856 - Association - 17095
# 13856 - Association - 239083
# 13856 - Association - 12452
# 13856 - Association - 12576
# 13856 - Association - 12444
# 13856 - Association - 12228
# 13856 - Association - 12530
# 13856 - Association - 20715
# 13856 - Association - 228775
# 13856 - Association - 12125
# 13856 - Association - 18712
# 13856 - Association - 223775
# 13856 - Association - 14455
# 13856 - Bind - 13857
# 72049 - Positive_Correlation - 13856
# 13857 - Association - 18708
# 13857 - Association - D011086
# 13857 - Association - D000740
# 13857 - Association - 239083
# 13857 - Association - 12452
# 13857 - Association - 12576
# 13857 - Association - 12444
# 13857 - Association - 12228
# 13857 - Association - 12530
# 13857 - Association - 72049
# 9456 - Association - D018698
# 9456 - Association - D007980
# 9456 - Association - D006212
# 9456 - Association - D004409
# D007980 - Negative_Correlation - D010300
# D007980 - Positive_Correlation - D006212
# D007980 - Positive_Correlation - D004409
# rs4704559 - Negative_Correlation - D007980
# rs4704559 - Negative_Correlation - D006212
# rs4704559 - Negative_Correlation - D004409
# D008750 - Positive_Correlation - D007022
# D012701 - Association - D015116
# D012701 - Positive_Correlation - D008750
# D012701 - Positive_Correlation - D007022
# 6774 - Association - 7422
# 7422 - Positive_Correlation - 3791
# 7422 - Positive_Correlation - D017382
# 66021 - Positive_Correlation - D017382
# 50507 - Positive_Correlation - 6774
# 50507 - Positive_Correlation - 3791
# 50507 - Association - 7422
# 50507 - Positive_Correlation - D017382
# 114243 - Positive_Correlation - D017382
# D010100 - Positive_Correlation - D012164
# 85431 - Positive_Correlation - D017382
# 85431 - Association - 25589
# D013629 - Association - 20423
# D013629 - Association - 12387
# 12162 - Association - 12387
# 12159 - Association - 12387
# D000071056 - Association - 12162
# D000071056 - Association - 12159
# 12387 - Association - 55994
# 12387 - Association - 17129
# 12387 - Association - 17125
# 12387 - Association - 17702
# 12387 - Association - D029502
# 12387 - Association - 20423
# 12387 - Association - D000071056
# D001224 - Negative_Correlation - D010862
# D001224 - Negative_Correlation - C573355
# D010862 - Positive_Correlation - D013226
# D010862 - Positive_Correlation - 11423
# D010862 - Positive_Correlation - D012640
# D018698 - Negative_Correlation - D010862
# D018698 - Negative_Correlation - C573355
# D005680 - Positive_Correlation - D010862
# D005680 - Positive_Correlation - C573355
# C573355 - Negative_Correlation - D003967
# C573355 - Negative_Correlation - D012871
# C573355 - Negative_Correlation - D013226
# C573355 - Cotreatment - D010862
# C573355 - Positive_Correlation - 11423
# C573355 - Negative_Correlation - D007249
# C573355 - Negative_Correlation - D012640
# 170496 - Association - D007674
# 170496 - Association - D020123
# D016572 - Association - D017392
# D016572 - Association - 25647
# D016572 - Association - 81736
# D016572 - Association - 59086
# D016572 - Association - 64032
# D016572 - Association - 286934
# D016572 - Association - 24842
# D016572 - Association - 25737
# D016572 - Association - 56718
# D016572 - Positive_Correlation - D007674
# D007674 - Association - D017392
# D007674 - Association - 25647
# D007674 - Association - 81736
# D007674 - Association - 59086
# D007674 - Association - 64032
# D007674 - Association - 286934
# D007674 - Association - 24842
# D007674 - Association - 25737
# D007674 - Association - 56718
# D020123 - Association - D011507
# D020123 - Comparison - D016572
# D020123 - Negative_Correlation - D007674
# C537417 - Positive_Correlation - D000077590
# C537417 - Positive_Correlation - D013390
# C537417 - Positive_Correlation - p|SUB|V|204|D
# rs1803274 - Association - D002092
# rs1799807 - Association - rs1803274
# rs1799807 - Association - D002092
# D055191 - Positive_Correlation - c|SUB|T|695|A
# D055191 - Positive_Correlation - D013390
# D055191 - Positive_Correlation - p|SUB|V|204|D
# 590 - Negative_Correlation - C537417
# 590 - Association - D002092
# 590 - Association - D055191
# 590 - Association - D013390
# 590 - Association - D001049
# D013390 - Association - c|SUB|T|695|A
# D013390 - Positive_Correlation - D001049
# D001049 - Positive_Correlation - D000077590
# p|SUB|V|204|D - Association - rs1803274
# p|SUB|V|204|D - Association - rs1799807
# p|SUB|V|204|D - Association - D002092
# p|SUB|V|204|D - Association - D013390
# p|SUB|V|204|D - Positive_Correlation - D001049
# C547455 - Negative_Correlation - 1508
# C547455 - Negative_Correlation - 5328
# C547455 - Negative_Correlation - 4318
# 3939 - Association - D011471
# 3939 - Positive_Correlation - 1508
# 3939 - Positive_Correlation - 5328
# 3939 - Positive_Correlation - 4318
# 3939 - Negative_Correlation - C547455
# 3939 - Association - D009369
# 2056 - Association - D008055
# 2057 - Association - 1432
# 2057 - Association - 4067
# 2057 - Association - 6198
# 2057 - Association - 6776
# 2057 - Association - 207
# D007410 - Association - 288264
# D003920 - Association - 25712
# D003920 - Positive_Correlation - D011070
# D003920 - Association - 686326
# D003920 - Association - 288264
# 3454 - Association - D003922
# 3456 - Association - D003922
# 686326 - Association - D003922
# D003922 - Association - 3630
# 288264 - Association - D003922
# 6833 - Association - D003324
# 6833 - Association - D003924
# 6833 - Association - D013453
# D003924 - Negative_Correlation - D013453
# rs757110 - Negative_Correlation - D003324
# rs757110 - Negative_Correlation - D003924
# rs757110 - Association - D013453
# D013453 - Negative_Correlation - D003324
# 3630 - Positive_Correlation - 6833
# 3630 - Positive_Correlation - D013453
# D008070 - Positive_Correlation - D007249
# D055371 - Association - 14062
# D007249 - Association - 7412
# D007249 - Association - 3383
# C100008 - Association - 14061
# C100008 - Negative_Correlation - D008070
# C100008 - Association - D055371
# C100008 - Negative_Correlation - D007249
# C100008 - Negative_Correlation - 7412
# C100008 - Negative_Correlation - 3383
# C100008 - Association - 5566
# C100008 - Association - 5906
# C100008 - Association - 5879
# C100008 - Bind - 5734
# 5734 - Association - D007249
# 5734 - Positive_Correlation - 5566
# 5734 - Positive_Correlation - 5906
# 5734 - Positive_Correlation - 5879
# 14526 - Association - D007003
# 14526 - Negative_Correlation - 58991
# 3630 - Negative_Correlation - D003922
# 58991 - Negative_Correlation - D007003
# D013311 - Positive_Correlation - 58991
# D013311 - Positive_Correlation - D006943
# 2642 - Association - D006943
# 2642 - Association - D003922
# D001786 - Negative_Correlation - 14527
# D001786 - Association - 208188
# D001786 - Negative_Correlation - D013311
# 51738 - Association - D001786
# 51738 - Association - D005947
# D007249 - Positive_Correlation - 5716
# 5716 - Positive_Correlation - 22339
# D000077157 - Negative_Correlation - D006528
# 53380 - Association - D006528
# 53380 - Association - D007249
# 53380 - Association - D009369
# 53380 - Positive_Correlation - 17075
# 53380 - Positive_Correlation - 12151
# 53380 - Positive_Correlation - 16193
# 53380 - Bind - 15170
# 53380 - Negative_Correlation - D000077157
# 53380 - Positive_Correlation - 20848
# 1081 - Association - 2796
# 2796 - Association - D006220
# D006966 - Association - 2796
# D006220 - Positive_Correlation - D006966
# D007752 - Negative_Correlation - D000305
# D013726 - Association - D000305
# D013726 - Negative_Correlation - D007752
# D002318 - Positive_Correlation - D000305
# D002318 - Association - D013726
# C536353 - Negative_Correlation - D005227
# C536353 - Positive_Correlation - c|DEL|1078-1182|
# C536353 - Negative_Correlation - 37
# D019308 - Association - C536353
# 37 - Positive_Correlation - D019308
# D001523 - Association - 4988
# D000242 - Association - 25601
# D006160 - Association - 25601
# 25601 - Association - D018847
# 25601 - Association - D053610
# D012964 - Association - 25601
# D000326 - Association - 215
# 472 - Association - D002524
# D001260 - Association - 472
# c|INS||137 - Association - D002524
# c|INS||137 - Positive_Correlation - D001260
# D009223 - Association - 13400
# D002118 - Negative_Correlation - 13400
# 1457 - Association - C537475
# 4722 - Bind - 4726
# 4722 - Association - 1457
# 4722 - Association - C537475
# 5578 - Association - C537475
# 4720 - Bind - 4726
# 4720 - Bind - 4722
# 4720 - Association - C537475
# 4720 - Association - 5578
# D000077213 - Cotreatment - D005013
# D014635 - Cotreatment - D005013
# D014635 - Cotreatment - D000077213
# D004832 - Negative_Correlation - D005013
# D004832 - Negative_Correlation - D000077213
# D004832 - Negative_Correlation - D014635
# D004832 - Positive_Correlation - D020888
# D004832 - Positive_Correlation - D002220
# D002220 - Comparison - D020888
# D009207 - Positive_Correlation - D002220
# rs1050501 - Positive_Correlation - D008180
# D009393 - Association - 971
# 2213 - Association - D008180
# 971 - Association - 2213
# D008180 - Association - 971
# 12517 - Association - D008180
# c|SUB|G||A - Positive_Correlation - D011471
# c|DUP||G| - Positive_Correlation - D009369
# D009369 - Association - 367
# 354 - Association - 367
# c|DUP||CAG_GGC| - Positive_Correlation - D011471
# D011471 - Association - 354
# 367 - Association - D011471
# 2814 - Bind - 7450
# 2814 - Association - D001606
# 2811 - Bind - 7450
# 2811 - Association - D001606
# 7450 - Association - D001606
# 2815 - Bind - 7450
# 2815 - Association - D001606
# rs5030764 - Positive_Correlation - D001606
# p|SUB|NRTP|86_89|A - Positive_Correlation - D001606
# c|DEL|1952|9 - Positive_Correlation - D001606
# 1638 - Association - D010859
# rs74315339 - Positive_Correlation - D005901
# 1545 - Association - D005901
# 10133 - Association - D005901
# C537550 - Association - 8104
# C537550 - Association - rs74315339
# C537550 - Association - 1545
# C537550 - Association - 10133
# C537550 - Association - 4653
# 4653 - Association - D005901
# c|SUB|A|1284|C - Positive_Correlation - D018382
# 1081 - Positive_Correlation - 6955
# D013974 - Association - 6955
# D013974 - Positive_Correlation - p|SUB|E|333|D
# D014284 - Association - 6955
# D014284 - Positive_Correlation - p|SUB|E|333|D
# 6955 - Association - D018382
# D018382 - Positive_Correlation - D013963
# D018382 - Association - 1081
# D018382 - Positive_Correlation - D013974
# D018382 - Positive_Correlation - D014284
# p|SUB|E|333|D - Positive_Correlation - D018382
# D017382 - Positive_Correlation - D009369
# 2879 - Association - D003643
# 2879 - Association - D001943
# rs713041 - Positive_Correlation - D003643
# D001943 - Positive_Correlation - rs757229
# D001943 - Positive_Correlation - rs713041
# D020522 - Association - 2073
# D020522 - Association - 472
# D020522 - Association - 5567
# D020522 - Association - 9411
# D020522 - Association - 26271
# D009369 - Association - rs1045485
# D009369 - Association - c|INDEL|-652|6
# D002166 - Association - 7157
# c|DEL|-652|6 - Positive_Correlation - D002166
# c|DEL|-652|6 - Positive_Correlation - D000077195
# 841 - Association - D009369
# 841 - Association - 7157
# 841 - Association - D002166
# 841 - Association - D000077195
# D002658 - Negative_Correlation - D013974
# D007037 - Negative_Correlation - D013974
# 7067 - Association - D003248
# 7067 - Association - D008607
# 7067 - Association - D001848
# D013974 - Negative_Correlation - 22094
# D013974 - Negative_Correlation - 12640
# D013974 - Association - D001848
# 21833 - Association - D006130
# 21833 - Association - D001848
# 8737 - Positive_Correlation - 836
# C582180 - Negative_Correlation - D009369
# 330 - Negative_Correlation - C582180
# 330 - Association - D009369
# 329 - Negative_Correlation - C582180
# 329 - Association - D009369
# 56616 - Negative_Correlation - 330
# 56616 - Negative_Correlation - 329
# 56616 - Association - D009369
# D009369 - Association - 14103
# D009369 - Association - 18646
# 7124 - Positive_Correlation - 11035
# 7124 - Positive_Correlation - 8737
# 7124 - Positive_Correlation - 836
# 7124 - Association - D009369
# 7124 - Association - D012509
# 4790 - Association - D009369
# 4790 - Positive_Correlation - 7124
# 4790 - Association - D012509
# 4790 - Bind - 4790
# 5970 - Positive_Correlation - 7124
# 5970 - Association - D012509
# 5970 - Bind - 4790
# D005355 - Association - 12013
# D001761 - Positive_Correlation - D011658
# 12013 - Positive_Correlation - 16193
# 12013 - Positive_Correlation - 21803
# 12013 - Negative_Correlation - 14775
# 12013 - Negative_Correlation - 15368
# 12013 - Positive_Correlation - D011658
# 12013 - Positive_Correlation - D001761
# 16880 - Positive_Correlation - 17701
# 16878 - Association - 17701
# 16878 - Bind - 16880
# 20848 - Association - 16880
# 20848 - Association - 16878
# 16452 - Association - 16880
# 16452 - Association - 16878
# 16452 - Association - 20848
# D001216 - Association - D000641
# D001216 - Association - D001224
# D008691 - Association - D007938
# D008691 - Positive_Correlation - 4988
# 11065 - Association - D054198
# 759 - Association - D054198
# D001215 - Positive_Correlation - OMIM:615574
# D001215 - Association - D001216
# D001215 - Cotreatment - D008691
# D001215 - Negative_Correlation - D007938
# D001215 - Negative_Correlation - D054198
# 4988 - Association - D007938
# 4988 - Negative_Correlation - D054198
# 4988 - Positive_Correlation - D001215
# D012878 - Negative_Correlation - D000975
# D012878 - Positive_Correlation - 4953
# D012878 - Positive_Correlation - D011453
# 23418 - Association - D057130
# 23418 - Association - D012174
# D006956 - Association - 23418
# rs62636275 - Association - D057130
# rs62636275 - Association - D006956
# rs62636275 - Association - D012174
# D008569 - Positive_Correlation - D018817
# D003072 - Positive_Correlation - D018817
# c|DEL|1494|6 - Association - D009369
# c|DEL|1494|6 - Association - D015179
# 7298 - Association - D009362
# 7298 - Association - D009369
# 7298 - Association - D015179
# D005472 - Cotreatment - D002955
# D005472 - Cotreatment - D007978
# D015179 - Negative_Correlation - D005472
# D015179 - Negative_Correlation - D002955
# D015179 - Negative_Correlation - D007978
# D020158 - Positive_Correlation - D005998
# D014635 - Positive_Correlation - D001927
# D014635 - Positive_Correlation - D002819
# 443502 - Negative_Correlation - 443538
# 443502 - Negative_Correlation - 443387
# 26416 - Negative_Correlation - 652
# 17129 - Association - 12159
# 17129 - Association - 652
# 17125 - Association - 12159
# 17125 - Association - 652
# 14715 - Positive_Correlation - 16866
# 16866 - Positive_Correlation - 14714
# 16323 - Association - 17127
# 16323 - Association - 17126
# 16323 - Positive_Correlation - 443538
# 16323 - Positive_Correlation - 443387
# 16323 - Positive_Correlation - 14308
# 16323 - Association - 12640
# 16323 - Association - 14714
# 14714 - Positive_Correlation - 26416
# 14714 - Association - 12912
# 14714 - Association - 26417
# 14714 - Association - 26413
# 14714 - Positive_Correlation - 443538
# 14714 - Positive_Correlation - 443387
# 14714 - Positive_Correlation - 14308
# 14714 - Association - 12640
# 83729 - Association - 14308
# 83729 - Association - 12640
# 3624 - Association - 14308
# 3624 - Association - 12640
# 652 - Negative_Correlation - 14715
# 652 - Negative_Correlation - 16866
# 652 - Positive_Correlation - 16323
# 652 - Association - 14308
# 652 - Association - 12640
# 652 - Positive_Correlation - 14714
# 652 - Association - 83729
# 652 - Association - 3624
# c|INDEL||6 - Positive_Correlation - D005472
# c|INDEL||6 - Association - D015179
# D012004 - Association - c|INDEL||6
# D012004 - Association - 7298
# 7298 - Positive_Correlation - D005472
# 7298 - Association - D015179
# D009369 - Association - c|INDEL||6
# D009369 - Association - 7298
# c|DEL|194|6 - Association - D015179
# D015179 - Association - c|DUP||28
# D015179 - Negative_Correlation - D005472
# D015179 - Association - c|SUB|G||C
# D013739 - Association - rs3730089
# D013739 - Association - D011085
# D019326 - Association - D011085
# rs3730089 - Positive_Correlation - D019326
# rs3730089 - Association - D011085
# 5295 - Association - D013739
# 5295 - Association - D019326
# 5295 - Association - D011085
# 5295 - Association - D005947
# 5295 - Association - 3630
# 3630 - Association - D005947
# D014148 - Positive_Correlation - D012640
# D005978 - Association - 81736
# 24598 - Association - D005978
# 24598 - Association - 2876
# 24598 - Positive_Correlation - D003042
# 81736 - Negative_Correlation - 24598
# 81736 - Association - 2876
# 81736 - Negative_Correlation - D003042
# D000077236 - Negative_Correlation - D019970
# D000077236 - Negative_Correlation - D008569
# D000077236 - Negative_Correlation - D007859
# D003042 - Association - 2876
# D003042 - Negative_Correlation - D000077236
# D003042 - Positive_Correlation - D008569
# D003042 - Positive_Correlation - D007859
# D003907 - Positive_Correlation - D006861
# D003907 - Positive_Correlation - D006973
# 301034 - Negative_Correlation - D017382
# 301034 - Negative_Correlation - D015431
# 301034 - Negative_Correlation - D006861
# 301034 - Negative_Correlation - D006973
# 301034 - Negative_Correlation - D003907
# D007501 - Association - 301034
# 12978 - Positive_Correlation - 14281
# 12977 - Positive_Correlation - 14281
# 12977 - Bind - 12978
# 12977 - Positive_Correlation - 16153
# 12977 - Positive_Correlation - 16411
# 12977 - Association - 16187
# 16153 - Association - D008070
# 16187 - Positive_Correlation - 16153
# 16187 - Positive_Correlation - 16411
# 14183 - Association - D009369
# 14183 - Association - 20674
# D019636 - Association - 14183
# 774 - Positive_Correlation - D002118
# D011189 - Association - 774
# D002118 - Association - D011189
# D002118 - Association - D004421
# D004421 - Positive_Correlation - rs550921485
# D004421 - Positive_Correlation - rs775863165
# 3208 - Association - 774
# 3208 - Association - D011189
# 3208 - Positive_Correlation - D002118
# 3208 - Bind - 783
# 3208 - Association - D004421
# 14580 - Association - D000544
# 109305 - Association - 16534
# D009422 - Association - D000069285
# D009422 - Association - 5663
# D009422 - Association - 351
# D009422 - Association - 11820
# D009422 - Association - 16534
# D000069285 - Association - 351
# D000069285 - Association - D008569
# 5663 - Association - D008569
# 351 - Association - D008569
# 11820 - Association - D008569
# D005911 - Association - 14580
# 56717 - Association - D005911
# 2475 - Association - D005911
# 207 - Association - D005911
# 11651 - Association - D005911
# 3783 - Association - D000544
# 3783 - Association - D009422
# 3783 - Association - D008569
# 3783 - Association - D005911
# 16534 - Association - D000544
# 16534 - Negative_Correlation - 14580
# 16534 - Negative_Correlation - 13198
# 16534 - Negative_Correlation - 14828
# 16534 - Association - D000069285
# 16534 - Association - D008569
# 16534 - Association - D005911
# 16534 - Negative_Correlation - 56717
# 16534 - Negative_Correlation - 11651
# D002118 - Association - 109305
# D002118 - Association - D005911
# D002118 - Association - 56717
# D002118 - Association - 2475
# D002118 - Association - 207
# D002118 - Association - 11651
# D002118 - Association - 3783
# D002118 - Association - 16534
# c|DEL|4995|30 - Association - D003715
# c|DEL||30 - Association - D003715
# c|DEL||30 - Association - D014766
# C563856 - Positive_Correlation - c|INS|457_458|G
# C563856 - Association - 7259
# D011595 - Negative_Correlation - D000525
# D011595 - Negative_Correlation - D017374
# D001068 - Negative_Correlation - D000525
# D001068 - Negative_Correlation - D017374
# D007319 - Negative_Correlation - D000525
# D007319 - Negative_Correlation - D017374
# D003866 - Negative_Correlation - D000525
# D003866 - Negative_Correlation - D017374
# D003402 - Negative_Correlation - D003975
# D003402 - Negative_Correlation - D001971
# D003975 - Negative_Correlation - D001480
# D001971 - Negative_Correlation - D001480
# D001480 - Positive_Correlation - D000410
# D001480 - Positive_Correlation - D001219
# D001480 - Positive_Correlation - D003402
# D001480 - Positive_Correlation - D000525
# D001480 - Positive_Correlation - D017374
# D005334 - Positive_Correlation - D000410
# D005334 - Positive_Correlation - D001219
# D005334 - Positive_Correlation - D003402
# D005334 - Negative_Correlation - D003975
# D005334 - Negative_Correlation - D001971
# D014202 - Negative_Correlation - D003975
# D014202 - Negative_Correlation - D001971
# D009127 - Negative_Correlation - D003975
# D009127 - Negative_Correlation - D001971
# D011596 - Negative_Correlation - D003975
# D011596 - Negative_Correlation - D001971
# D000525 - Positive_Correlation - D005334
# D000525 - Positive_Correlation - D014202
# D000525 - Positive_Correlation - D009127
# D000525 - Positive_Correlation - D011596
# D000525 - Positive_Correlation - D009459
# D017374 - Positive_Correlation - D005334
# D017374 - Positive_Correlation - D014202
# D017374 - Positive_Correlation - D009127
# D017374 - Positive_Correlation - D011596
# D017374 - Drug_Interaction - D000525
# D017374 - Positive_Correlation - D009459
# D017116 - Negative_Correlation - D013256
# D010146 - Negative_Correlation - D013256
# D011843 - Negative_Correlation - D013256
# D009422 - Positive_Correlation - D013256
# C030262 - Positive_Correlation - D020335
# C030262 - Positive_Correlation - D006987
# D002045 - Positive_Correlation - D020335
# D002045 - Positive_Correlation - D006987
# D011128 - Positive_Correlation - D014221
# D011128 - Positive_Correlation - D002045
# D013256 - Positive_Correlation - D011128
# 6441 - Bind - D000073893
# 6441 - Association - D007249
# 653509 - Bind - D000073893
# 653509 - Association - D007249
# c|Allele|K|223 - Association - D003643
# D002241 - Association - 729238
# c|SUB|Q|223|K - Positive_Correlation - D003643
# c|SUB|Q|223|K - Association - D002241
# c|SUB|Q|223|K - Positive_Correlation - D008589
# 729238 - Bind - D000073893
# 729238 - Association - D007249
# 729238 - Association - D003643
# 729238 - Association - D008589
# 4487 - Association - C538049
# rs121917720 - Positive_Correlation - C538049
# 5083 - Association - C538049
# 2271 - Association - D014233
# 2271 - Association - C538191
# 2271 - Association - D009369
# 2271 - Association - C535516
# 2271 - Association - D001927
# c|SUB|G|1201|C - Positive_Correlation - D005938
# D006973 - Association - 2908
# D009765 - Association - 2908
# D005938 - Association - D006854
# D005938 - Association - D003907
# D005938 - Bind - 2908
# D005938 - Positive_Correlation - D004342
# p|SUB|D|401|H - Positive_Correlation - D008659
# p|SUB|D|401|H - Positive_Correlation - D006973
# p|SUB|D|401|H - Positive_Correlation - D009765
# p|SUB|D|401|H - Association - D003907
# p|SUB|D|401|H - Positive_Correlation - D005938
# 2908 - Association - D008659
# 2908 - Association - 23426
# 2908 - Association - D003907
# D004342 - Association - c|SUB|G|1201|C
# D004342 - Association - p|SUB|D|401|H
# D004342 - Association - 2908
# 268482 - Negative_Correlation - 3265
# 24064 - Negative_Correlation - 26417
# 24064 - Negative_Correlation - 26413
# 24064 - Negative_Correlation - 109880
# 24064 - Negative_Correlation - 3265
# 24063 - Negative_Correlation - 26417
# 24063 - Negative_Correlation - 26413
# 24063 - Negative_Correlation - 109880
# 24063 - Negative_Correlation - 3265
# 12577 - Positive_Correlation - 3265
# 12575 - Negative_Correlation - 12577
# 12575 - Negative_Correlation - 12576
# 12576 - Positive_Correlation - 3265
# 3265 - Positive_Correlation - 19130
# 3265 - Association - D009369
# 3265 - Positive_Correlation - 12444
# 3265 - Positive_Correlation - 12443
# rs28931594 - Positive_Correlation - C536168
# p|SUB|A|88|V - Positive_Correlation - C536168
# c|SUB|C|263|T - Positive_Correlation - C536168
# 2706 - Association - C536168
# D017488 - Negative_Correlation - D017255
# D010212 - Negative_Correlation - D017255
# D000052 - Negative_Correlation - D017255
# C536168 - Negative_Correlation - D017255
# rs121913529 - Association - D009369
# 16477 - Association - 50754
# 16477 - Association - 12578
# D009369 - Association - 50754
# 12576 - Negative_Correlation - D009369
# 12576 - Association - 16653
# 12575 - Negative_Correlation - D009369
# 12575 - Association - 16653
# 97998 - Negative_Correlation - D009369
# 97998 - Association - 16653
# 18033 - Negative_Correlation - D009369
# 18033 - Association - 16653
# 16653 - Association - D009369
# 16653 - Association - D008175
# 19823 - Association - 18015
# 19823 - Association - 58801
# 19823 - Positive_Correlation - 26413
# 19823 - Negative_Correlation - 16477
# 19823 - Negative_Correlation - 12578
# 19823 - Association - D009369
# 19823 - Association - D008175
# 19823 - Association - 12576
# 19823 - Association - 12575
# 19823 - Association - 97998
# 19823 - Association - 18033
# 19823 - Positive_Correlation - 16653
# D001152 - Positive_Correlation - D009369
# D006331 - Association - 24185
# D004317 - Positive_Correlation - D066126
# D004317 - Negative_Correlation - D009369
# D004317 - Association - 24185
# D004317 - Positive_Correlation - D006331
# 24225 - Association - 64639
# 24225 - Association - 56718
# 24225 - Bind - 25054
# 24225 - Positive_Correlation - 24185
# 24225 - Negative_Correlation - D006331
# 24225 - Negative_Correlation - D004317
# D001281 - Positive_Correlation - D004317
# D009136 - Positive_Correlation - D004317
# C535648 - Negative_Correlation - D004317
# D004317 - Positive_Correlation - D066126
# D004317 - Positive_Correlation - D001145
# D016257 - Positive_Correlation - D002118
# p|DEL|695-725| - Association - D002118
# D004533 - Association - D002118
# D004533 - Association - 55503
# 55503 - Negative_Correlation - D002118
# c|DEL|3472|C - Positive_Correlation - D016108
# c|DEL||C - Positive_Correlation - D016108
# 1294 - Association - D016108
# D016108 - Positive_Correlation - c|SUB|G||A
# D016108 - Positive_Correlation - c|SUB|G|IVS51+1|A
# rs6318 - Association - D016574
# 3358 - Association - D016574
# rs1048943 - Negative_Correlation - D011471
# D011471 - Association - g|SUB|T|3801|C
# D011471 - Association - 1543
# D009369 - Negative_Correlation - D000617
# D009369 - Negative_Correlation - D000583
# D006402 - Negative_Correlation - D000617
# D006402 - Negative_Correlation - D000583
# D007674 - Positive_Correlation - D003404
# D000583 - Negative_Correlation - D007239
# D000583 - Negative_Correlation - D009503
# D000583 - Positive_Correlation - D007674
# rs2622604 - Positive_Correlation - D001855
# rs2622604 - Positive_Correlation - D000077146
# D001855 - Association - 9429
# D000077146 - Positive_Correlation - D003967
# D000077146 - Negative_Correlation - D015179
# D000077146 - Negative_Correlation - D008175
# D000077146 - Positive_Correlation - D001855
# D000077146 - Association - 9429
# 30161 - Negative_Correlation - 30204
# 30161 - Association - 359834
# 563085 - Negative_Correlation - 30204
# 563085 - Association - 25884
# 563085 - Association - 91851
# 563085 - Association - 69121
# 1278 - Association - D050723
# 1278 - Association - D010024
# rs137853893 - Association - D010013
# D010013 - Association - 1278
# D010013 - Association - 121340
# 3579 - Association - D055113
# 3576 - Association - D007249
# 3576 - Association - D055113
# 3577 - Association - D007249
# 3577 - Bind - 3576
# 3577 - Association - D008175
# rs2234671 - Negative_Correlation - D008175
# rs11079788 - Negative_Correlation - D003876
# rs12141189 - Association - D010457
# rs12141189 - Association - D008050
# 3458 - Association - D008050
# 1437 - Association - D010457
# 1437 - Association - D008050
# rs2738751 - Association - D010457
# rs2738751 - Association - D008050
# rs17250932 - Association - D008050
# 7124 - Association - D008050
# 3596 - Association - D010457
# 3596 - Association - D008050
# 3567 - Association - D010457
# 3567 - Association - D008050
# 3142 - Association - 3569
# 3142 - Association - 113791973
# 3142 - Association - 3458
# 3142 - Association - 1437
# 3142 - Association - D010457
# 3142 - Association - D008050
# 3142 - Association - 7124
# 3142 - Association - 3596
# 3142 - Association - 3567
# 3142 - Association - D001249
# 30009 - Association - D003876
# 30009 - Association - D008050
# 30009 - Association - 7124
# 30009 - Association - 3596
# 30009 - Association - 3567
# 30009 - Association - D001249
# D005315 - Association - 20655
# 12330 - Positive_Correlation - D016640
# D003920 - Association - 20655
# 22433 - Association - D016640
# 78943 - Association - D016640
# 13666 - Association - D016640
# 229317 - Association - D016640
# D016640 - Positive_Correlation - 13198
# 20655 - Association - 12330
# 20655 - Association - 22433
# 20655 - Association - 78943
# 20655 - Association - 13666
# 20655 - Association - 229317
# 20655 - Association - 13198
# 20655 - Association - D016640
# 21926 - Positive_Correlation - 84050
# D011832 - Association - 295589
# D011832 - Association - 498609
# D011832 - Association - 84050
# p|SUB|C|311|A - Association - p|SUB|L|351|A
# p|SUB|C|311|A - Association - p|SUB|C|314|A
# p|SUB|C|314|A - Association - p|SUB|L|351|A
# 11651 - Association - 53978
# 18708 - Association - 11651
# 18708 - Association - 53978
# 26417 - Association - 53978
# 26413 - Association - 53978
# 65086 - Association - 15270
# 14745 - Association - 15270
# 500987 - Association - 53978
# 685055 - Negative_Correlation - C512273
# 300711 - Association - 81736
# 300711 - Negative_Correlation - C512273
# 53978 - Positive_Correlation - 21926
# 53978 - Association - 16590
# 53978 - Association - 110454
# 53978 - Association - 83557
# 53978 - Association - 15270
# 53978 - Association - 65086
# 53978 - Association - 14745
# 53978 - Association - 295589
# 498609 - Association - 500987
# 498609 - Association - 81736
# 498609 - Negative_Correlation - C512273
# 498609 - Positive_Correlation - 300711
# 498609 - Association - 295589
# 84050 - Association - 295589
# 84050 - Association - 53978
# 84050 - Association - 498609
# 4130 - Association - D006528
# 207 - Association - D006528
# 4751 - Association - D009362
# 4751 - Association - D009369
# 4751 - Positive_Correlation - 4130
# 4751 - Positive_Correlation - 207
# 4751 - Association - D006528
# D049932 - Association - 4683
# D049932 - Positive_Correlation - c|DEL||5
# rs5370 - Association - D050177
# rs5370 - Association - D009765
# 1906 - Association - D050177
# 1906 - Association - D009765
# c|Allele|G|111 - Positive_Correlation - C565789
# 8864 - Association - C565789
# rs2476601 - Positive_Correlation - D003922
# D003922 - Association - 26191
# D003922 - Positive_Correlation - rs56048322
# p|SUB|V|16|A - Positive_Correlation - D052878
# D052878 - Association - 6648
# 6648 - Association - D002137
# 5027 - Association - D003866
# 5027 - Association - D001714
# 2475 - Association - D002289
# D000068338 - Negative_Correlation - 2475
# D000068338 - Negative_Correlation - D002289
# 1956 - Association - D002289
# D010984 - Negative_Correlation - D002289
# D000077144 - Association - 1557
# D000077144 - Negative_Correlation - D003324
# D009369 - Negative_Correlation - 4221
# c|INS||C - Positive_Correlation - D018761
# c|INS||C - Positive_Correlation - D010911
# c|INS||C - Positive_Correlation - D006965
# 4221 - Association - D018761
# 4221 - Association - D010911
# 4221 - Association - D006965
# c|INS|1546_1547|C - Positive_Correlation - D018761
# c|INS|1546_1547|C - Positive_Correlation - D010911
# c|INS|1546_1547|C - Positive_Correlation - D006965
# c|INS|1546_1547|C - Association - c|SUB|C|IVS3+18|T
# rs1695 - Association - D011470
# rs1695 - Positive_Correlation - D011471
# 2950 - Association - D011470
# 2950 - Association - D011471
# D015283 - Positive_Correlation - D016171
# D016593 - Positive_Correlation - D016171
# D009369 - Association - 2147
# D009369 - Association - 174
# 7066 - Association - D008103
# D006528 - Positive_Correlation - 7066
# D006528 - Positive_Correlation - 3576
# D006528 - Positive_Correlation - 6374
# D006528 - Positive_Correlation - 6352
# D006528 - Positive_Correlation - 6351
# D006528 - Positive_Correlation - 6348
# D006528 - Positive_Correlation - 6347
# 3576 - Association - D008103
# 6374 - Association - D008103
# 6352 - Association - D008103
# 6351 - Association - D008103
# 6348 - Association - D008103
# 6347 - Association - D008103
# D019798 - Association - D007249
# D007249 - Association - 3576
# D007249 - Association - 6374
# D007249 - Association - 6352
# D007249 - Association - 6351
# D007249 - Association - 6348
# D007249 - Association - 6347
# D007249 - Association - 3569
# 1401 - Association - D007249
# 76895 - Association - D009134
# 76895 - Association - 1639
# 76895 - Association - 1778
# 76895 - Association - 23299
# 5870 - Positive_Correlation - 76895
# 5870 - Positive_Correlation - 1639
# 5870 - Positive_Correlation - 1778
# 1639 - Association - D009134
# 1778 - Association - D009134
# 1778 - Bind - 1639
# 23299 - Association - D009134
# 23299 - Bind - 1639
# 23299 - Bind - 1778
# D000438 - Positive_Correlation - D028361
# D000438 - Positive_Correlation - D064420
# D000438 - Positive_Correlation - D007249
# D013831 - Negative_Correlation - 15251
# D013831 - Association - D013832
# 56878 - Association - D013832
# D007249 - Association - 58801
# D007249 - Association - 12177
# D007249 - Association - 12176
# D007249 - Association - 20296
# D007511 - Association - 15251
# D000860 - Association - 15251
# 15251 - Negative_Correlation - 56878
# 15251 - Association - D007249
# 15251 - Association - 58801
# 15251 - Association - 12177
# 15251 - Association - 12176
# 15251 - Association - 20296
# D013832 - Positive_Correlation - D000438
# D013832 - Association - 11747
# D013832 - Association - 58801
# D013832 - Association - 12177
# D013832 - Association - 12176
# D013832 - Association - 20296
# D013832 - Positive_Correlation - 15251
# D000900 - Positive_Correlation - D007674
# D000900 - Positive_Correlation - D009395
# D000305 - Negative_Correlation - D009395
# D009395 - Positive_Correlation - D017963
# 24111 - Positive_Correlation - D001919
# 24111 - Positive_Correlation - D006973
# 24111 - Positive_Correlation - 12640
# 24111 - Positive_Correlation - 19109
# 24111 - Association - D001523
# 24111 - Positive_Correlation - D003866
# 24111 - Positive_Correlation - D001008
# D009569 - Association - D009422
# c|DUP||CCTTT|14 - Association - D005902
# D005902 - Association - c|DUP||CCTTT|13
# D005902 - Association - c|DUP||CCTTT|10
# 4843 - Association - D001766
# 4843 - Association - D005901
# 4843 - Association - D005902
# C012589 - Negative_Correlation - D008175
# C012589 - Positive_Correlation - 81704
# D000077209 - Negative_Correlation - D008175
# D000077209 - Positive_Correlation - 81704
# 81704 - Association - D009369
# 81704 - Negative_Correlation - D001943
# 81704 - Negative_Correlation - D008175
# rs121908072 - Positive_Correlation - D034381
# 117531 - Association - D034381
# D019465 - Association - 2260
# D019465 - Association - 3664
# rs7802 - Positive_Correlation - C562509
# rs7802 - Positive_Correlation - C536528
# rs7802 - Association - C566121
# rs7802 - Association - D000848
# rs2235371 - Positive_Correlation - C562509
# rs2235371 - Positive_Correlation - C536528
# rs2235371 - Association - C566121
# rs2235371 - Association - D000848
# rs17015215 - Positive_Correlation - C562509
# rs17015215 - Positive_Correlation - C536528
# rs17015215 - Association - C566121
# rs17015215 - Association - D000848
# rs861019 - Positive_Correlation - C562509
# rs861019 - Positive_Correlation - C536528
# rs861019 - Association - C566121
# rs861019 - Association - D000848
# 2260 - Association - D000848
# 3664 - Association - 7039
# 3664 - Association - 4487
# 3664 - Association - C562509
# 3664 - Association - C536528
# 3664 - Association - C566121
# 3664 - Association - D000848
# p|SUB|E||X - Positive_Correlation - D005489
# c|SUB|G|898|T - Positive_Correlation - D005489
# D005489 - Association - 64840
# p|SUB|E|300|X - Positive_Correlation - D005489
# rs545688154 - Association - D002118
# D010009 - Association - 1464
# D010009 - Association - 3371
# D010009 - Positive_Correlation - rs545688154
# 176 - Association - 3371
# 176 - Association - D010009
# 57817 - Association - C562385
# C562385 - Positive_Correlation - p|SUB|A|118|D
# C562385 - Positive_Correlation - c|SUB|C|468|T
# C562385 - Positive_Correlation - c|SUB|C|467|A
# C562385 - Positive_Correlation - c|INS|2172_2173|CCCC
# C562385 - Positive_Correlation - c|INS||CCCC
# C562385 - Positive_Correlation - p|FS|P|686||
# D007501 - Association - D018798
# 164656 - Negative_Correlation - 57817
# 164656 - Association - C562385
# 164656 - Association - D018798
# D006679 - Positive_Correlation - D016578
# D016578 - Positive_Correlation - D015658
# 3569 - Association - D015431
# 3952 - Association - D015431
# 56729 - Association - D015431
# 1268 - Association - D009765
# 1268 - Association - D015431
# rs1049353 - Association - D015431
# 3620 - Association - D015658
# 3620 - Association - D000275
# D014364 - Association - 15930
# D014364 - Association - D000275
# 15978 - Association - 26416
# 15930 - Association - 15978
# 15930 - Association - 26416
# 15930 - Association - D000275
# 15930 - Positive_Correlation - 155871
# C090942 - Negative_Correlation - 15567
# C090942 - Negative_Correlation - 18126
# C090942 - Negative_Correlation - 16193
# C090942 - Negative_Correlation - 21926
# C090942 - Negative_Correlation - 15930
# C090942 - Negative_Correlation - 155871
# 26416 - Association - D015658
# 26416 - Negative_Correlation - C090942
# 26416 - Association - D000275
# 155871 - Association - 15978
# 155871 - Positive_Correlation - 15567
# 155871 - Positive_Correlation - 18126
# 155871 - Positive_Correlation - 16193
# 155871 - Positive_Correlation - 21926
# 155871 - Association - 26416
# 155871 - Positive_Correlation - D000275
# 311450 - Positive_Correlation - D018377
# 311450 - Positive_Correlation - D005768
# 296078 - Positive_Correlation - D018377
# 296078 - Positive_Correlation - D005768
# 29433 - Positive_Correlation - D018377
# 29433 - Positive_Correlation - D005768
# 29431 - Positive_Correlation - D018377
# 29431 - Positive_Correlation - D005768
# 292756 - Positive_Correlation - D018377
# 292756 - Positive_Correlation - D005768
# 24203 - Positive_Correlation - 25298
# C541795 - Negative_Correlation - 24203
# C541795 - Negative_Correlation - 50689
# C541795 - Negative_Correlation - 116590
# C541795 - Association - 64465
# C541795 - Association - 363875
# C541795 - Association - D001839
# C541795 - Negative_Correlation - 25298
# C541795 - Negative_Correlation - 29432
# 298947 - Negative_Correlation - C085911
# 298947 - Negative_Correlation - D000077191
# 24889 - Association - 25298
# D001839 - Positive_Correlation - 24203
# 25298 - Association - 83805
# 25298 - Positive_Correlation - 50689
# ...
# 89829 - Negative_Correlation - 84598
# 89829 - Negative_Correlation - 25125
# D005227 - Association - D009765
# D004041 - Positive_Correlation - D009765
# D004317 - Association - D000244
# D004317 - Negative_Correlation - D000255
# D004317 - Association - D008055
# D004317 - Positive_Correlation - D006331
# D004317 - Positive_Correlation - D066126
# D009765 - Negative_Correlation - D000255
# D009765 - Association - 65248
# D009765 - Association - 25747
# D009765 - Association - 54315
# D009765 - Association - 25708
# D009765 - Association - 246253
# D009765 - Positive_Correlation - D004317
# D017114 - Positive_Correlation - D000069438
# D001219 - Association - D056486
# D001219 - Association - D000069499
# D019821 - Positive_Correlation - D001219
# D019821 - Negative_Correlation - 3156
# D019821 - Association - 7361
# D019821 - Drug_Interaction - D000069438
# D056486 - Positive_Correlation - D019821
# D056486 - Association - 7361
# D056486 - Positive_Correlation - D000069499
# C532833 - Association - D019821
# D000069438 - Positive_Correlation - D056486
# D000069438 - Association - C532833
# D000069438 - Negative_Correlation - 7361
# D015283 - Negative_Correlation - D003866
# D000069499 - Positive_Correlation - D017114
# D000069499 - Positive_Correlation - D017093
# D013256 - Negative_Correlation - D009404
# D013256 - Negative_Correlation - D005923
# D058186 - Positive_Correlation - D019386
# D058186 - Positive_Correlation - D004164
# D019386 - Negative_Correlation - D003404
# D019386 - Negative_Correlation - D005923
# D004164 - Negative_Correlation - D005923
# D011507 - Positive_Correlation - D019386
# D011507 - Positive_Correlation - D004164
# D003924 - Negative_Correlation - C057619
# D003924 - Negative_Correlation - D005907
# D005913 - Comparison - C057619
# D005913 - Comparison - D005907
# D005913 - Negative_Correlation - D003924
# D005913 - Positive_Correlation - D003324
# D005905 - Comparison - C057619
# D005905 - Comparison - D005907
# D005905 - Negative_Correlation - D003924
# D005905 - Positive_Correlation - D003324
# D013453 - Negative_Correlation - D003924
# D003324 - Positive_Correlation - D013453
# D014508 - Association - D007674
# D019808 - Negative_Correlation - D006973
# D019808 - Negative_Correlation - 24180
# D019808 - Negative_Correlation - D005923
# D019808 - Negative_Correlation - D014511
# D019808 - Negative_Correlation - D007676
# D019808 - Negative_Correlation - D005355
# D019808 - Negative_Correlation - D001284
# D019808 - Negative_Correlation - D011507
# D019808 - Negative_Correlation - D005921
# D019808 - Negative_Correlation - D007674
# D019808 - Negative_Correlation - D004317
# D004317 - Positive_Correlation - D005923
# D004317 - Positive_Correlation - D007674
# D014810 - Positive_Correlation - D000975
# D014810 - Negative_Correlation - D000252
# D014810 - Positive_Correlation - D000254
# D014810 - Positive_Correlation - D017301
# D014810 - Negative_Correlation - D008055
# D014810 - Negative_Correlation - D009203
# D014810 - Negative_Correlation - D007545
# D010936 - Cotreatment - D014810
# D010936 - Positive_Correlation - D000975
# D010936 - Negative_Correlation - D000252
# D010936 - Positive_Correlation - D000254
# D010936 - Positive_Correlation - D017301
# D010936 - Negative_Correlation - D008055
# D010936 - Negative_Correlation - D009203
# D010936 - Negative_Correlation - D007545
# D007545 - Negative_Correlation - D000975
# D007545 - Positive_Correlation - D000252
# D007545 - Negative_Correlation - D000254
# D007545 - Negative_Correlation - D017301
# D007545 - Association - D008055
# D007545 - Positive_Correlation - D009203
# D017180 - Positive_Correlation - D010042
# D004837 - Positive_Correlation - D001145
# D011433 - Negative_Correlation - D010042
# D011433 - Negative_Correlation - D017180
# D011433 - Negative_Correlation - D001145
# D011433 - Negative_Correlation - D004837
# D011433 - Negative_Correlation - D019344
# D011433 - Negative_Correlation - D005947
# D007545 - Negative_Correlation - D011433
# D007545 - Positive_Correlation - D005227
# D007545 - Positive_Correlation - D019344
# D007545 - Positive_Correlation - D005947
# C066201 - Negative_Correlation - D009202
# C066201 - Negative_Correlation - D006331
# C066201 - Negative_Correlation - D009203
# C066201 - Negative_Correlation - D007545
# D028361 - Association - D000244
# D028361 - Positive_Correlation - D007545
# D007545 - Negative_Correlation - 24404
# D007545 - Negative_Correlation - 24786
# D007545 - Positive_Correlation - 24264
# D007545 - Positive_Correlation - 25721
# D007545 - Positive_Correlation - 24533
# D007545 - Positive_Correlation - D009202
# D007545 - Positive_Correlation - D006331
# D007545 - Negative_Correlation - 24248
# D007545 - Positive_Correlation - D008315
# D007545 - Positive_Correlation - D009203
# D020258 - Positive_Correlation - D018817
# D018817 - Positive_Correlation - D006948
# D018817 - Positive_Correlation - D008569
# D018817 - Association - D002188
# D018817 - Positive_Correlation - D007859
# D006948 - Positive_Correlation - D002188
# D008569 - Positive_Correlation - D002188
# D007859 - Positive_Correlation - D002188
# 19225 - Association - D011141
# 11827 - Negative_Correlation - D008094
# D015232 - Negative_Correlation - 20495
# D015232 - Negative_Correlation - 11827
# D015232 - Association - D011141
# D015232 - Association - D008094
# D018021 - Positive_Correlation - D015232
# D018021 - Positive_Correlation - D011141
# D018021 - Positive_Correlation - 64292
# D008094 - Negative_Correlation - 20495
# D008094 - Positive_Correlation - D011141
# 64292 - Association - D015232
# 64292 - Positive_Correlation - D011141
# 64292 - Positive_Correlation - D008094
# D002351 - Positive_Correlation - D004487
# D003911 - Association - D017308
# 24260 - Negative_Correlation - C042375
# 24260 - Association - D010042
# 24260 - Association - D000157
# 24260 - Association - D001145
# 100379235 - Negative_Correlation - C042375
# 100379235 - Association - D010042
# 100379235 - Association - D000157
# 100379235 - Association - D001145
# C042375 - Negative_Correlation - D010862
# D002118 - Positive_Correlation - D010042
# D002118 - Positive_Correlation - D000157
# D002118 - Negative_Correlation - D010862
# D001145 - Positive_Correlation - D010042
# D001145 - Positive_Correlation - D000157
# D010862 - Association - 24260
# D010862 - Association - 100379235
# D010862 - Negative_Correlation - D010042
# D010862 - Negative_Correlation - D000157
# D010862 - Negative_Correlation - D001145
# D010862 - Negative_Correlation - D017180|D014693
# D005996 - Positive_Correlation - D007022
# D005996 - Positive_Correlation - D008569
# D009553 - Association - D002118
# D009553 - Association - D007022
# D009553 - Negative_Correlation - D005996
# D009553 - Negative_Correlation - D008569
# D012893 - Positive_Correlation - D003042
# C048833 - Association - D003042
# C048833 - Negative_Correlation - D012893
# C401121 - Negative_Correlation - D009437
# C401121 - Negative_Correlation - D006930
# C401121 - Negative_Correlation - D007249
# D009020 - Negative_Correlation - D009437
# D009020 - Cotreatment - C401121
# D009020 - Negative_Correlation - D006930
# D009020 - Negative_Correlation - D007249
# D013311 - Positive_Correlation - D003929
# D002351 - Positive_Correlation - D007249
# D015032 - Negative_Correlation - D002945
# D012643 - Negative_Correlation - D002945
# D002945 - Positive_Correlation - D058186
# D002945 - Positive_Correlation - 18125
# D002945 - Positive_Correlation - 18033
# D002945 - Positive_Correlation - 22060
# D002945 - Positive_Correlation - 12367
# D002945 - Positive_Correlation - D003404
# D002945 - Positive_Correlation - D001806
# D002945 - Positive_Correlation - D007674
# C024989 - Negative_Correlation - 18125
# C024989 - Negative_Correlation - 18033
# C024989 - Negative_Correlation - 22060
# C024989 - Negative_Correlation - 12367
# C024989 - Negative_Correlation - D005978
# C024989 - Negative_Correlation - 20655
# C024989 - Negative_Correlation - 21926
# C024989 - Positive_Correlation - D015032
# C024989 - Positive_Correlation - D012643
# C024989 - Negative_Correlation - D010984
# C024989 - Negative_Correlation - D009569
# C024989 - Negative_Correlation - D008055
# C024989 - Negative_Correlation - D003404
# C024989 - Negative_Correlation - D001806
# C024989 - Negative_Correlation - D007674
# C024989 - Negative_Correlation - D002945
# D001480 - Positive_Correlation - D006220
# D001480 - Positive_Correlation - C522667
# D012559 - Negative_Correlation - D006220
# C522667 - Negative_Correlation - D011618
# C522667 - Negative_Correlation - D001714
# C522667 - Negative_Correlation - D012559
# C522667 - Comparison - D006220
# D003520 - Cotreatment - D005047
# D003520 - Negative_Correlation - D015458|D016399
# D005047 - Negative_Correlation - D015458|D016399
# C104457 - Positive_Correlation - D006402
# C104457 - Positive_Correlation - D059352
# C104457 - Positive_Correlation - D009422
# C104457 - Cotreatment - D003520
# C104457 - Cotreatment - D005047
# C104457 - Negative_Correlation - D015458|D016399
# D004298 - Positive_Correlation - D009461
# D004298 - Positive_Correlation - D020258
# D019805 - Negative_Correlation - D020258
# D019805 - Negative_Correlation - D008694
# D007980 - Association - D004298
# D007980 - Association - D019805
# D007980 - Association - D020258
# D008694 - Positive_Correlation - D009461
# D008694 - Drug_Interaction - D004298
# D008694 - Positive_Correlation - D020258
# 24316 - Negative_Correlation - D006220
# D018698 - Association - D002375
# D018698 - Association - D006220
# C031231 - Negative_Correlation - D002375
# C031231 - Negative_Correlation - D006220
# D016291 - Negative_Correlation - D002375
# D016291 - Negative_Correlation - D006220
# 24408 - Positive_Correlation - D016202
# 24408 - Negative_Correlation - C031231
# 24408 - Negative_Correlation - D016291
# 24408 - Association - D002375
# D006220 - Positive_Correlation - D002375
# D003072 - Positive_Correlation - D000927
# D003072 - Positive_Correlation - D002220
# D003072 - Positive_Correlation - D010634
# D003474 - Negative_Correlation - D007249
# D003474 - Negative_Correlation - D002220
# D003474 - Negative_Correlation - D010634
# D003474 - Negative_Correlation - D003072
# C029036 - Negative_Correlation - D019636
# C029036 - Negative_Correlation - D003072
# C029036 - Negative_Correlation - D008569
# C029036 - Negative_Correlation - D007859
# C029036 - Negative_Correlation - D000544
# C029036 - Negative_Correlation - D013311
# D013311 - Positive_Correlation - D003072
# D013311 - Positive_Correlation - D000544
# D012640 - Association - 29705
# D001556 - Negative_Correlation - 29705
# D001556 - Positive_Correlation - D012640
# D001556 - Positive_Correlation - D004827
# D019331 - Negative_Correlation - D012640
# 24598 - Negative_Correlation - D019331
# D001120 - Positive_Correlation - D012640
# D009569 - Positive_Correlation - D012640
# D009569 - Association - D001556
# D009569 - Association - D019331
# D009569 - Association - 24598
# D009569 - Association - D001120
# D007069 - Positive_Correlation - D003556
# D007069 - Positive_Correlation - D006470
# D007069 - Positive_Correlation - D030342
# D015080 - Negative_Correlation - D030342
# D015080 - Negative_Correlation - D007069
# D003976 - Association - 50689
# D003976 - Association - 116590
# D003976 - Positive_Correlation - D008077
# D003976 - Positive_Correlation - D014280
# D003976 - Positive_Correlation - D002784
# D003976 - Positive_Correlation - D006949
# D003976 - Negative_Correlation - 300438
# D003976 - Association - D008055
# 300438 - Association - D006949
# C029036 - Positive_Correlation - 50689
# C029036 - Positive_Correlation - 116590
# C029036 - Association - D002784
# C029036 - Negative_Correlation - D003976
# C029036 - Negative_Correlation - D006949
# C029036 - Positive_Correlation - 300438
# C029036 - Association - D008055
# 24889 - Negative_Correlation - D020109
# D009020 - Positive_Correlation - D000647
# D009020 - Positive_Correlation - D008569
# D009020 - Association - 25706
# D012844 - Negative_Correlation - D000647
# D012844 - Negative_Correlation - D008569
# D012844 - Negative_Correlation - D009020
# D012844 - Association - 25706
# C058121 - Negative_Correlation - D012844
# 25706 - Negative_Correlation - C058121
# D058186 - Positive_Correlation - D003287
# D017693 - Negative_Correlation - D007674
# D017693 - Comparison - D004110
# D003287 - Positive_Correlation - D007674
# D004110 - Negative_Correlation - D002118
# D004110 - Negative_Correlation - D007674
# D004110 - Negative_Correlation - D003287
# D008874 - Negative_Correlation - D009207
# D008874 - Negative_Correlation - D005045
# D005283 - Comparison - D008874
# D005283 - Negative_Correlation - D009207
# D005283 - Negative_Correlation - D005045
# D010146 - Positive_Correlation - D005045
# D009069 - Positive_Correlation - D005045
# D005045 - Positive_Correlation - D009207
# C067431 - Positive_Correlation - D008569
# 25147 - Negative_Correlation - C067431
# D013629 - Positive_Correlation - D008569
# 2099 - Negative_Correlation - D013629
# D005485 - Positive_Correlation - D008569
# 367 - Negative_Correlation - D005485
# D013311 - Negative_Correlation - 369140
# D013311 - Negative_Correlation - 369068
# D013311 - Positive_Correlation - D008569
# D013739 - Association - 369140
# D013739 - Association - 369068
# D013739 - Negative_Correlation - D008569
# D013739 - Negative_Correlation - D013311
# C417083 - Negative_Correlation - D006526
# C417083 - Cotreatment - C486464
# D012254 - Cotreatment - C417083
# D012254 - Negative_Correlation - D006526
# D012254 - Cotreatment - C486464
# 1576 - Association - D019821
# D019821 - Positive_Correlation - D009135
# D019821 - Drug_Interaction - D000998
# D019821 - Negative_Correlation - D006526
# D019821 - Positive_Correlation - D012206
# C486464 - Negative_Correlation - D006526
# C486464 - Drug_Interaction - D019821
# C486464 - Positive_Correlation - D012206
# /Users/kashifmoin/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /Users/kashifmoin/anaconda3/lib/python3.11/site-packages/transformers/modeling_utils.py:446: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location="cpu")
# Some weights of the model checkpoint at microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
def parse_relation_text(rel_text):
    """
    Parses a relation text string into its constituent components: entity1, relation_type, and entity2.
    The expected format of the input string is: "entity1 - relation_type - entity2".
    Returns:
        tuple: A tuple containing (entity1, relation_type, entity2). If the input format is incorrect,
               it returns (None, None, None).
    
    Example:
        rel_text = "Aspirin - inhibits - COX-2"
        entity1, relation_type, entity2 = parse_relation_text(rel_text)
        # entity1 -> "Aspirin"
        # relation_type -> "inhibits"
        # entity2 -> "COX-2"
    """
    parts = rel_text.split(" - ") # Split the string by the delimiter " - ".
    if len(parts) == 3:
        return parts[0].strip(), parts[1].strip(), parts[2].strip() # Strip any leading or trailing whitespace from each component.
    # If the format is incorrect, return None for each component.
    return None, None, None

def select_triplet(anchor_idx, relation_texts, embeddings, sim_matrix, pos_threshold=0.90, hard_threshold=0.80):
    """
    For a given anchor (index), select the best positive and hard negative relations.
    A positive is defined as a relation with the same relation type as the anchor.
    A hard negative is defined as one with a different relation type but with high similarity.
    Returns:
        tuple: (anchor_text, best_positive_text, best_hard_negative_text)
    
    Example:
        relation_texts = [
            "Aspirin - inhibits - COX-2",
            "Ibuprofen - inhibits - COX-1",
            "Vitamin C - activates - Immune System",
            "Paracetamol - treats - Headache"
        ]
        # Assuming embeddings and sim_matrix are precomputed appropriately.
        anchor_idx = 0  # "Aspirin - inhibits - COX-2"
        anchor, positive, hard_negative = select_triplet(anchor_idx, relation_texts, embeddings, sim_matrix)
        # positive might be "Ibuprofen - inhibits - COX-1" (same relation type 'inhibits')
        # hard_negative might be "Paracetamol - treats - Headache" (different relation type but high similarity)
    """
    anchor_text = relation_texts[anchor_idx] # Retrieve the anchor relation text based on the provided index.
    _, anchor_rel_type, _ = parse_relation_text(anchor_text) # Parse the anchor text to extract entity1, relation_type, and entity2.
    
    best_positive = None
    best_positive_sim = -1.0 # Start with the lowest possible similarity.
    
    best_hard_negative = None
    best_hard_sim = -1.0 # Start with the lowest possible similarity.
    
    # Iterate over all candidate relations to find the best matches.
    for idx, candidate_text in enumerate(relation_texts):
        if idx == anchor_idx: # Skip the anchor itself.
            continue
        sim_score = sim_matrix[anchor_idx][idx] # Retrieve the precomputed similarity score between the anchor and the candidate.
        # Parse the candidate relation text.
        _, candidate_rel_type, _ = parse_relation_text(candidate_text)
        
        # Check for positive pair: same relation type and similarity above threshold.
        if candidate_rel_type == anchor_rel_type and sim_score > pos_threshold:
            # Update if this candidate has a higher similarity than the current best.
            if sim_score > best_positive_sim:
                best_positive = candidate_text
                best_positive_sim = sim_score
        
        # Check for hard negative: different relation type and similarity above hard_threshold.
        if candidate_rel_type != anchor_rel_type and sim_score > hard_threshold:
            # Update if this candidate has a higher similarity than the current best.
            if sim_score > best_hard_sim:
                best_hard_negative = candidate_text
                best_hard_sim = sim_score
                
    # Return the anchor text along with the best positive and hard negative matches found.
    return anchor_text, best_positive, best_hard_negative

# Example usage:
if __name__ == "__main__":
    # For demonstration, select the anchor as the first relation text (index 0).
    anchor_idx = 0
    anchor, positive, hard_negative = select_triplet(anchor_idx, relation_texts, embeddings, sim_matrix)
    
    print("Anchor Relation:", anchor)
    print("Best Positive Pair:", positive)
    print("Best Hard Negative:", hard_negative)
# Out:
# Anchor Relation: 3175 - Association - D003924
# Best Positive Pair: 300438 - Association - D006949
# Best Hard Negative: D006160 - Bind - 189429

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from transformers import BertTokenizer

# Define the Hard Negative Contrastive Loss function.
class HardNegativeContrastiveLoss(nn.Module):
    def __init__(self, margin=0.5):
        """
        Initializes the HardNegativeContrastiveLoss with a specified margin.
        """
        super(HardNegativeContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, anchor, positive, hard_negative):
        # Calculate cosine similarities between anchor-positive and anchor-hard_negative pairs.
        pos_sim = F.cosine_similarity(anchor, positive)      # Similarity should be high.
        hard_sim = F.cosine_similarity(anchor, hard_negative)  # Similarity should be low.
        
        # Loss main aim is to ensure hard negative similarity is lower than positive similarity by at least the margin.
        loss = F.relu(self.margin + hard_sim - pos_sim)
        return loss.mean()

# A helper function to run one training step.
def train_step(model, loss_fn, optimizer, tokenizer, anchor_text, positive_text, hard_negative_text):
    """
    Executes a single training step: tokenization, embedding extraction, loss computation, and optimization.
    Returns:
        float: The computed loss value for this training step.
    """
    # Tokenize and obtain embeddings for each text.
    anchor_inputs = tokenizer(anchor_text, return_tensors="pt", padding=True, truncation=True)
    positive_inputs = tokenizer(positive_text, return_tensors="pt", padding=True, truncation=True)
    hard_negative_inputs = tokenizer(hard_negative_text, return_tensors="pt", padding=True, truncation=True)
    
    # Extract embeddings using the model.
    anchor_emb = model(anchor_inputs['input_ids'], anchor_inputs['attention_mask'])
    positive_emb = model(positive_inputs['input_ids'], positive_inputs['attention_mask'])
    hard_negative_emb = model(hard_negative_inputs['input_ids'], hard_negative_inputs['attention_mask'])
    
    # Compute the loss using the hard negative contrastive loss function.
    loss = loss_fn(anchor_emb, positive_emb, hard_negative_emb)
    
    # Perform backpropagation and an optimization step.
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    return loss.item()

# Example usage:
if __name__ == "__main__":
    # Load the model and tokenizer using PubMedBERT.
    model_name = "microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract"
    tokenizer = BertTokenizer.from_pretrained(model_name)
    model = RelationExtractionModel(bert_model_name=model_name)
    
    # Instantiate the hard negative contrastive loss function and the optimizer.
    loss_fn = HardNegativeContrastiveLoss(margin=0.5)
    optimizer = optim.Adam(model.parameters(), lr=1e-5)
    
    # For demonstration, assume these texts were selected as anchor, positive, and hard negative samples:
    anchor_text = "D001943 - Positive_Correlation - c|INS|5382|C"
    positive_text = "D001943 - Positive_Correlation - c|DEL|4153|A"
    hard_negative_text = "672 - Association - D001943"
    
    # Run one training step and print the loss value.
    loss_value = train_step(model, loss_fn, optimizer, tokenizer, anchor_text, positive_text, hard_negative_text)
    print("Training step loss:", loss_value)
# Out:
# /Users/kashifmoin/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /Users/kashifmoin/anaconda3/lib/python3.11/site-packages/transformers/modeling_utils.py:446: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location="cpu")
# Some weights of the model checkpoint at microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Training step loss: 0.341005802154541

# %%
import numpy as np
from tqdm import tqdm

def optimized_select_triplets(relation_texts, sim_matrix, pos_threshold=0.90, hard_threshold=0.80):
    """
    Optimized selection of training triplets (anchor, positive, hard negative)
    from the relation texts based on the precomputed cosine similarity matrix.
    Returns:
        list of tuples: Each tuple
    """
    triplets = [] # List to store the selected triplets.
    n = len(relation_texts) # Total number of relation texts.
    
    # Iterate over each relation text to consider it as an anchor.
    for i, anchor_text in enumerate(relation_texts):
        # Parse the anchor text to extract its components.
        _, anchor_rel, _ = parse_relation_text(anchor_text)
        pos_indices = [] # List to store indices of positive samples.
        hard_indices = [] # List to store indices of hard negative samples.
        
        # Iterate over all other relation texts to find positives and hard negatives.
        for j in range(n):
            if j == i:
                continue # Skip comparing the anchor with itself.
                
            # Parse the candidate relation text.    
            _, cand_rel, _ = parse_relation_text(relation_texts[j])
            sim_score = sim_matrix[i, j]
            
            # Identify positive samples: same relation type and similarity above threshold.
            if cand_rel == anchor_rel and sim_score >= pos_threshold:
                pos_indices.append(j)
                
            # Identify hard negative samples: different relation type and similarity above threshold.
            elif cand_rel != anchor_rel and sim_score >= hard_threshold:
                hard_indices.append(j)
                
        # If both positive and hard negative samples are found, select the one with best cosine similarity.
        if pos_indices and hard_indices:
            # Select the positive sample with the highest similarity to the anchor.
            best_pos_idx = pos_indices[np.argmax([sim_matrix[i, j] for j in pos_indices])]
            # Select the hard negative sample with the highest similarity to the anchor.
            best_hard_idx = hard_indices[np.argmax([sim_matrix[i, j] for j in hard_indices])]
            # Append the selected triplet to the list.
            triplets.append((relation_texts[i], relation_texts[best_pos_idx], relation_texts[best_hard_idx]))
    return triplets

# Generate optimized triplets using the extracted relation_texts and precomputed sim_matrix.
triplets = optimized_select_triplets(relation_texts, sim_matrix, pos_threshold=0.90, hard_threshold=0.80)
print(f"Total training triplets found: {len(triplets)}")

# Define optimizer and loss function.
optimizer = optim.Adam(model.parameters(), lr=1e-5)
loss_fn = HardNegativeContrastiveLoss(margin=0.5)

# Full training loop over multiple epochs with a progress bar.
num_epochs = 5
for epoch in range(num_epochs):
    total_loss = 0.0 # Initialize total loss for the epoch.
    # Iterate over each triplet and perform a training step.
    for anchor_text, positive_text, hard_negative_text in tqdm(triplets, desc=f"Epoch {epoch+1}"):
        loss_value = train_step(model, loss_fn, optimizer, tokenizer, anchor_text, positive_text, hard_negative_text)
        total_loss += loss_value # Accumulate the loss.
        
    avg_loss = total_loss / len(triplets)
    print(f"Epoch {epoch+1}/{num_epochs}, Average Loss: {avg_loss:.4f}")
# Out:
# Total training triplets found: 4178
# Epoch 1: 100%|████████████████████████████| 4178/4178 [5:21:03<00:00,  4.61s/it]
# Epoch 1/5, Average Loss: 0.0050
# Epoch 2: 100%|████████████████████████████| 4178/4178 [5:30:25<00:00,  4.75s/it]
# Epoch 2/5, Average Loss: 0.0005
# Epoch 3: 100%|████████████████████████████| 4178/4178 [1:20:36<00:00,  1.16s/it]
# Epoch 3/5, Average Loss: 0.0000
# Epoch 4: 100%|██████████████████████████████| 4178/4178 [40:22<00:00,  1.72it/s]
# Epoch 4/5, Average Loss: 0.0005
# Epoch 5: 100%|██████████████████████████████| 4178/4178 [44:17<00:00,  1.57it/s]
# Epoch 5/5, Average Loss: 0.0000

# %%
# Save the trained model's state_dict to a file.
torch.save(model.state_dict(), "trained_relation_extraction_model.pth")
print("✅ Model saved successfully as 'trained_relation_extraction_model.pth'")
# Out:
# ✅ Model saved successfully as 'trained_relation_extraction_model.pth'

# %%
from sklearn.metrics import silhouette_score, calinski_harabasz_score

def evaluate_clustering(all_embeddings, cluster_labels):
    """
    Evaluate clustering performance using common metrics:
    1. Silhouette Score
    2. Calinski-Harabasz Index
    
    Returns:
        dict: A dictionary containing the computed metrics.
    """
    # Silhouette Score: measures how similar each sample is to its own cluster compared to other clusters.
    # The score ranges from -1 to 1, where a higher score indicates that samples are well matched to their own cluster and poorly matched to neighboring clusters.
    sil_score = silhouette_score(all_embeddings, cluster_labels)
    
    # Calinski-Harabasz Index: also known as the Variance Ratio Criterion.
    # It is the ratio of the sum of between-clusters dispersion to within-cluster dispersion.
    # A higher Calinski-Harabasz score indicates better-defined clusters.
    ch_score = calinski_harabasz_score(all_embeddings, cluster_labels)
    
    return {
        "silhouette_score": sil_score,
        "calinski_harabasz_score": ch_score
    }

# Example usage after Step 6:
if __name__ == "__main__":
    
    # Evaluate the clustering performance using the defined function.
    metrics = evaluate_clustering(all_embeddings, cluster_labels)
    
    print("Clustering Performance Metrics:")
    print(f"Silhouette Score: {metrics['silhouette_score']:.4f}")
    print(f"Calinski-Harabasz Score: {metrics['calinski_harabasz_score']:.4f}")
# Out:
# Clustering Performance Metrics:
# Silhouette Score: 0.9210
# Calinski-Harabasz Score: 73200.9298

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
from scipy.optimize import linear_sum_assignment

# Extract ground truth relation types from relation texts.
# For example, if a relation text is "3175 - Association - D003924",
# the parse_relation_text function extracts "Association" as the relation type.
ground_truth_labels = [parse_relation_text(text)[1] for text in relation_texts]

# Identify unique relation types and assign each a unique integer identifier.
unique_labels = list(set(ground_truth_labels))
label_to_int = {label: i for i, label in enumerate(unique_labels)}

# Convert ground truth labels to their corresponding integer identifiers.
y_true = np.array([label_to_int[label] for label in ground_truth_labels])

# Predicted cluster labels obtained from your clustering algorithm (e.g., KMeans).
y_pred = np.array(cluster_labels)

def cluster_accuracy(y_true, y_pred):
    """
    Align cluster labels (y_pred) to ground truth labels (y_true)
    using the Hungarian algorithm and compute clustering accuracy.
    """
    # Compute the contingency matrix (confusion matrix between y_true and y_pred).
    cont_matrix = confusion_matrix(y_true, y_pred)
    
    # Apply the Hungarian algorithm to find the optimal one-to-one mapping
    # between predicted clusters and true labels that maximizes correct assignments.
    row_ind, col_ind = linear_sum_assignment(-cont_matrix)
    
    # Calculate the accuracy based on the optimal assignment.
    accuracy = cont_matrix[row_ind, col_ind].sum() / np.sum(cont_matrix)
    return accuracy, row_ind, col_ind

# Align clusters and compute clustering accuracy.
acc, row_ind, col_ind = cluster_accuracy(y_true, y_pred)
print(f"Clustering Accuracy: {acc:.4f}")

# Create a mapping from original cluster label to the aligned ground truth label.
mapping = {old: new for new, old in zip(col_ind, row_ind)}
# Apply the mapping to the predicted cluster labels.
y_pred_aligned = np.array([mapping[label] for label in y_pred])

# Compute precision, recall, and F1 score using macro averaging.
# Macro averaging calculates the metric independently for each class and then takes the average,
# treating all classes equally regardless of their size.
precision = precision_score(y_true, y_pred_aligned, average='macro')
recall = recall_score(y_true, y_pred_aligned, average='macro')
f1 = f1_score(y_true, y_pred_aligned, average='macro')

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Clustering Accuracy: 0.9679
# Precision: 0.3609
# Recall: 0.3750
# F1 Score: 0.3678
# /Users/kashifmoin/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
